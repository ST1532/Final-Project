# %%
import os
import matplotlib.pyplot as plt

from data import DIV2K
from model.srgan import generator, discriminator
from train import SrganTrainer, SrganGeneratorTrainer

# %matplotlib inline

# %%
# Location of model weights (needed for demo)
weights_dir = 'weights/srgan'
weights_file = lambda filename: os.path.join(weights_dir, filename)

os.makedirs(weights_dir, exist_ok=True)

# %% [markdown]
# Loading Datasets

# %%
div2k_train = DIV2K(scale=4, subset='train', downgrade='bicubic')
div2k_valid = DIV2K(scale=4, subset='valid', downgrade='bicubic')

# %%
train_ds = div2k_train.dataset(batch_size=16, random_transform=True)
valid_ds = div2k_valid.dataset(batch_size=16, random_transform=True, repeat_count=1)

# %% [markdown]
# pre-training

# %%
pre_trainer = SrganGeneratorTrainer(model=generator(), checkpoint_dir=f'.ckpt/pre_generator')
pre_trainer.train(train_ds,
                  valid_ds.take(10),
                  steps=1000000, 
                  evaluate_every=1000, 
                  save_best_only=False)

pre_trainer.model.save_weights(weights_file('pre_generator.h5'))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30388/2579474331.py in <module>
#       1 pre_trainer = SrganGeneratorTrainer(model=generator(), checkpoint_dir=f'.ckpt/pre_generator')
# ----> 2 pre_trainer.train(train_ds,
#       3                   valid_ds.take(10),
#       4                   steps=1000000,
#       5                   evaluate_every=1000,
#
# D:\super-resolution\train.py in train(self, train_dataset, valid_dataset, steps, evaluate_every, save_best_only)
#     125
#     126     def train(self, train_dataset, valid_dataset, steps=1000000, evaluate_every=1000, save_best_only=True):
# --> 127         super().train(train_dataset, valid_dataset, steps, evaluate_every, save_best_only)
#     128
#     129
#
# D:\super-resolution\train.py in train(self, train_dataset, valid_dataset, steps, evaluate_every, save_best_only)
# ...

# %% [markdown]
# GAN

# %%
gan_generator = generator()
gan_generator.load_weights(weights_file('pre_generator.h5'))

gan_trainer = SrganTrainer(generator=gan_generator, discriminator=discriminator())
gan_trainer.train(train_ds, steps=200000)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_30388/2590022365.py in <module>
#       3
#       4 gan_trainer = SrganTrainer(generator=gan_generator, discriminator=discriminator())
# ----> 5 gan_trainer.train(train_ds, steps=200000)
#
# D:\super-resolution\train.py in train(self, train_dataset, steps)
#     162             step += 1
#     163
# --> 164             pl, dl = self.train_step(lr, hr)
#     165             pls_metric(pl)
#     166             dls_metric(dl)
#
# D:\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# ...

# %%
gan_trainer.generator.save_weights(weights_file('gan_generator.h5'))
gan_trainer.discriminator.save_weights(weights_file('gan_discriminator.h5'))

# %% [markdown]
# implementation

# %%
pre_generator = generator()
gan_generator = generator()

pre_generator.load_weights(weights_file('pre_generator.h5'))
gan_generator.load_weights(weights_file('gan_generator.h5'))

# %%
from model.srgan import resolve_single

import numpy as np
from utils import load_image, plot_sample


def resolve_and_plot(lr_image_path):
    lr = load_image(lr_image_path)
    
    pre_sr = resolve_single(pre_generator, lr)
    gan_sr = resolve_single(gan_generator, lr)
    
    plt.figure(figsize=(20, 20))
    
    images = [lr, pre_sr, gan_sr]
    titles = ['LR', 'SR (PRE)', 'SR (GAN)']
    positions = [1, 3, 4]
    
    for i, (img, title, pos) in enumerate(zip(images, titles, positions)):
        plt.subplot(2, 2, pos)
        plt.imshow(img)
        plt.title(title)
        plt.xticks([])
        plt.yticks([])

# %%
import tkinter as tk
def show_win(path,path1):
    #窗口变量
    window = tk.Tk()

    #加载图片1
    image_file = tk.PhotoImage(file=path)
    #加载图片2
    image_file1 = tk.PhotoImage(file=path1)

    image1_height = image_file.height()
    image1_width = image_file.width()

    size="{}x{}".format(image1_width*2,image1_height)

    #窗口标题
    window.title('my window')
    #窗口大小
    window.geometry(size)
    #画布大小设置，白色背景1024*768
    canvas = tk.Canvas(window, bg='white', height=image1_height, width=image1_width*2)

    #定义图片1的位置
    image1 = canvas.create_image(0, 0, anchor='nw', image=image_file1 )
    #定义图片2的位置
    image = canvas.create_image(image1_width, 0, anchor='nw', image=image_file)
    canvas.pack()
    #程序
    window.mainloop()

# %%
resolve_and_plot('demo/0869x4-crop.png')
